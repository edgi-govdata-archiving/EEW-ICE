# %% [markdown]
# <a href="https://colab.research.google.com/github/edgi-govdata-archiving/EEW-ICE/blob/main/ICE_GOV_facs_EJSCREEN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ECHO_modules
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.8/317.8 MB 4.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.7/64.7 kB 4.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 25.6/25.6 MB 55.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 82.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 33.1 MB/s eta 0:00:00
# ...
#   Created wheel for pyspark: filename=pyspark-3.5.8-py2.py3-none-any.whl size=318352946 sha256=2ab0b7beb394511be881a48a0b6a3ccd2bf21315df49aeb448c26c786f84c081
#   Stored in directory: /root/.cache/pip/wheels/f0/f6/86/a9231691706c40d5bcc8c907f583e0ef90c075dcfa97e272d0
# Successfully built pyspark
# ...
#   Attempting uninstall: pyspark
#     Found existing installation: pyspark 4.0.2
#     Uninstalling pyspark-4.0.2:
#       Successfully uninstalled pyspark-4.0.2
#   Attempting uninstall: jupyter-leaflet
# ...

# %%
import pandas

facs = pandas.read_csv("ice.csv", dtype={"FAC_LAT": float, "FAC_LONG": float})

facs = facs[["fac", "FAC_LAT", "FAC_LONG"]]

# %%
facs = facs[~facs["FAC_LAT"].isna()]
facs
# Out:
#                                                    fac    FAC_LAT    FAC_LONG
# 0    Plymouth County Correctional FacilityBoston Fi...  41.932742  -70.657852
# 1    Wyatt Detention FacilityBoston Field Office950...  41.892811  -71.383200
# 2    Federal Correctional Institution - Berlin, NH ...  44.523499  -71.136130
# 3    Strafford County CorrectionsBoston Field Offic...  43.219230  -70.938608
# 4    Cumberland County JailBoston Field Office50 Co...  43.652372  -70.281138
# ..                                                 ...        ...         ...
# 136  Federal Detention Center, Honolulu (FDC Honolu...  21.333362 -157.928350
# 137  Guam Department of Corrections, Hagatna Detent...  13.475991  144.750484
# 138  CNMI Department of CorrectionsSan Francisco Fi...  15.158014  145.707280
# 139  Northwest ICE Processing Center (NWIPC)Seattle...  47.249412 -122.421140
# 140  Anchorage Correctional ComplexSeattle Field Of...  61.218380 -149.857650
#
# [141 rows x 3 columns]

# %%
from ECHO_modules.get_data import get_ejscreen

data = get_ejscreen(regions=facs, region_type="sites", buffer=3)

data
# Out:
#                                            EJAM Report  \
# 0    <a href="https://ejamapi-84652557241.us-centra...
# 1    <a href="https://ejamapi-84652557241.us-centra...
# 2    <a href="https://ejamapi-84652557241.us-centra...
# 3    <a href="https://ejamapi-84652557241.us-centra...
# 4    <a href="https://ejamapi-84652557241.us-centra...
# ..                                                 ...
# 136  <a href="https://ejamapi-84652557241.us-centra...
# 137  <a href="https://ejanalysis.com", target="_bla...
# 138  <a href="https://ejanalysis.com", target="_bla...
# 139  <a href="https://ejamapi-84652557241.us-centra...
# 140  <a href="https://ejamapi-84652557241.us-centra...
#
#                                           EJSCREEN Map  ejam_uniq_id  valid  \
# 0    <a href="https://pedp-ejscreen.azurewebsites.n...             1   True
# 1    <a href="https://pedp-ejscreen.azurewebsites.n...             2   True
# ...

# %%
data.to_csv("ice_ejscreen.csv")

# %%
data.columns.to_list()
# Out:
# ['EJAM Report',
#  'EJSCREEN Map',
#  'ejam_uniq_id',
#  'valid',
#  'invalid_msg',
#  'pop',
#  'lon',
#  'lat',
#  'ST',
#  'statename',
#  'in_how_many_states',
#  'REGION',
#  'ratio.to.avg.Demog.Index',
#  'ratio.to.avg.Demog.Index.Supp',
#  'ratio.to.avg.pctlowinc',
#  'ratio.to.avg.pctlingiso',
#  'ratio.to.avg.pctunemployed',
#  'ratio.to.avg.pctlths',
#  'ratio.to.avg.pctunder5',
#  'ratio.to.avg.pctover64',
#  'ratio.to.avg.pctmin',
#  'ratio.to.avg.pcthisp',
#  'ratio.to.avg.pctnhba',
#  'ratio.to.avg.pctnhaa',
#  'ratio.to.avg.pctnhaiana',
#  'ratio.to.avg.pctnhnhpia',
#  'ratio.to.avg.pctnhotheralone',
#  'ratio.to.avg.pctnhmulti',
#  'ratio.to.avg.pctnhwa',
#  'ratio.to.avg.pm',
#  'ratio.to.avg.o3',
#  'ratio.to.avg.no2',
#  'ratio.to.avg.dpm',
#  'ratio.to.avg.rsei',
#  'ratio.to.avg.traffic.score',
#  'ratio.to.avg.pctpre1960',
#  'ratio.to.avg.proximity.npl',
#  'ratio.to.avg.proximity.rmp',
#  'ratio.to.avg.proximity.tsdf',
#  'ratio.to.avg.ust',
# ...
